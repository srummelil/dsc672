# %%
years=[2010, 2011, 2012, 2013]
for iteration in range(0, len(years)):
    list_len=len(years)
    years.append(years.pop(0))
    train=years[1:len(years)]
    test=[]
    test.append(years[0])
    print("Iteration: {} Test: {} Train: {}".format(iteration, test, train))
# Out:
# Iteration: 0 Test: [2011] Train: [2012, 2013, 2010]
# Iteration: 1 Test: [2012] Train: [2013, 2010, 2011]
# Iteration: 2 Test: [2013] Train: [2010, 2011, 2012]
# Iteration: 3 Test: [2010] Train: [2011, 2012, 2013]
