# %%
# imports

import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df_init = pd.read_csv('consumption_model_dummies.csv')

# %%
df_init.set_index('Unnamed: 0', inplace=True, drop=True)

# %%
# drop all hour variables - keep weekday and month

# architecture

### All square foot / time period features input to standard feed-forward layer

### Variable weather features fed sequentially into LSTM/RNN/etc by hour


# Dataset definition

# | CONTANT VARIABLES | WEATHER(t) | WEATHER(t-1) | ... | WEATHER(t-n) | TOTAL_CONSUMPTION(t) |

# Split train / test based on random split?? Or first 9 months / last 3 months
