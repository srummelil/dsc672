# %%
import pandas as pd
import numpy as np

consumption = pd.read_pickle('./processed/consumption_master_with_SF.pkl')
production = pd.read_pickle('./processed/production_all_dates_and_variables.pkl')
production_all_src = pd.read_pickle('./processed/production_all_src.pkl')

#print(consumption.head())
#print(production.loc[production['Wind_KWH'] > 0.0].head())
#print(production_all_src.loc[production_all_src['Source']== 'Wind'].head())

#df.groupby(['col1', 'col2']).size().reset_index(name='counts')
#prod_pivot = production.groupby(production.index).size().reset_index(name='Count')
#print(prod_pivot.loc[prod_pivot['Count'] > 1])


for item in [['consumption', consumption], ['production', production], ['production_all_src', production_all_src]]:
    print(item[0])
    pivot = item[1].groupby(item[1].index).size().reset_index(name='Count')
    print(pivot.loc[pivot['Count'] > 1])
# Out:
# consumption
# Empty DataFrame
# Columns: [Time, Count]
# Index: []
# production
# Empty DataFrame
# Columns: [Time, Count]
# Index: []
# production_all_src
# Empty DataFrame
# Columns: [Time, Count]
# Index: []

# %%
print(production.head())
