# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~MattSundquist/10984/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~MattSundquist/10984/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="Box plot (5)", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~MattSundquist/10984/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('username', 'api_key')
trace1 = {
  "y": [14.3657362571, 16.0151322397, 17.2731966194, 12.9130734622, 15.3906424795, 15.7011708718, 14.550142424, 13.0029119465, 13.8728121158, 15.9618446583, 15.6433796201, 14.565816864, 13.5461307137, 15.4771115158, 14.8288342976, 15.6901630129, 15.9040298828, 15.9287496317], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Jan", 
  "showlegend": True, 
  "type": "box", 
  "uid": "6d0ecc", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace2 = {
  "y": [14.5573782744, 17.1090762832, 15.6779591236, 15.7137293124, 14.3986630521, 15.1526908223, 15.7696163976, 14.2637424762, 16.5851214871, 14.9660527468, 14.6503981956, 13.8224960123, 14.371316298, 14.5414270969, 14.7458610829, 16.9219841228], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Feb", 
  "showlegend": True, 
  "type": "box", 
  "uid": "f2a86f", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace3 = {
  "y": [15.8991463004, 13.7529592312, 14.8279807251, 14.2410055696, 15.328648197, 15.6686179038, 14.5345278572, 15.4298320785, 13.9895557715, 16.1150717623, 14.4281051786, 14.1727595839, 15.2397572251, 15.7297715875, 12.9529766737, 13.7988673782, 15.6945202237, 14.4930298155, 17.193560996], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Mar", 
  "showlegend": True, 
  "type": "box", 
  "uid": "5caf10", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace4 = {
  "y": [15.920145613, 16.1049369869, 15.7520248788, 15.5184528018, 16.2707674959, 13.660849902, 15.6484129852, 16.3922072399, 14.2904920924, 15.5835167491, 14.366046771, 14.9067252208, 14.0226562615, 15.0052587428, 15.8149213427, 14.4866516069], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Apr", 
  "showlegend": True, 
  "type": "box", 
  "uid": "a52f8d", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace5 = {
  "y": [12.6074678126, 17.1066896753, 14.0421860283, 14.5571652028, 14.4915218108, 14.0444430302, 13.8521463995, 15.1347649403, 15.073995892, 13.9576739654, 13.9051059668, 15.5712538881, 13.64318825, 14.5631632017, 16.5323867968, 15.4745306795], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "May", 
  "showlegend": True, 
  "type": "box", 
  "uid": "4ac978", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace6 = {
  "y": [15.4722000079, 15.2633617944, 15.4338594578, 16.1940273007, 15.6905564411, 14.3167584841, 14.6053586714, 15.1366609244, 14.6110581364, 16.1689057548, 15.8003047475, 15.3567061857, 15.9926935782, 13.6294320667, 15.3898333247, 15.5813915655, 16.019429999, 15.0272183874], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Jun", 
  "showlegend": True, 
  "type": "box", 
  "uid": "e51992", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace7 = {
  "y": [14.5044909928, 14.8764967673, 14.9145198013, 14.7779082966, 14.8622234398, 15.3206756629, 13.6827780706, 15.297053516, 17.4197018812, 14.6938346577, 13.9986714989, 14.3353056243, 15.5288214025, 14.0752338543, 14.6174894691, 15.9362995527, 15.467956795, 15.5451893403], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Jul", 
  "showlegend": True, 
  "type": "box", 
  "uid": "e6c8ee", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace8 = {
  "y": [14.895250764, 13.7575501937, 16.1069397649, 14.8358951827, 14.9440852585, 14.3235070625, 14.523176664, 15.1812342943, 14.5484356082, 12.8476035787, 15.9051872023, 15.4135543154, 15.6624105673, 15.4788195115, 14.2869759202, 15.3232657717, 13.8903945793, 13.5860553651, 15.3758685388], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Aug", 
  "showlegend": True, 
  "type": "box", 
  "uid": "b7fb98", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace9 = {
  "y": [14.3860755568, 13.3488248145, 13.6322172419, 14.6844120567, 15.1384610919, 14.8624373268, 13.4272581151, 15.4375835293, 14.7245820173, 15.8134450109, 14.7863897154, 15.2530776206, 16.0109277064, 15.7880573252, 17.4203170582, 16.8408399075, 16.6964854139], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Sep", 
  "showlegend": True, 
  "type": "box", 
  "uid": "a33292", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace10 = {
  "y": [15.8278170921, 14.9108500218, 14.5284763076, 12.8711230484, 13.4012529887, 14.7936852665, 14.8120879223, 14.7381302693, 14.4302013641, 14.6840114929, 14.1486004474, 15.7432063704, 14.5080048552, 14.4314238361, 15.3605759209, 15.7334088084, 16.9366065939], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Oct", 
  "showlegend": True, 
  "type": "box", 
  "uid": "749dca", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace11 = {
  "y": [16.5131340224, 15.6760611719, 16.4640497072, 15.8594195661, 15.7103215955, 13.6510516417, 14.8385792718, 15.3469762235, 15.5051698314, 14.232396718, 17.3687180667, 15.039717865, 15.3337950636, 14.9913548248, 15.3828073461, 15.3565851056], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Nov", 
  "showlegend": True, 
  "type": "box", 
  "uid": "6d11ca", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace12 = {
  "y": [14.4749348667, 13.7619250889, 15.6382064666, 14.7172537484, 15.796433584, 14.5157122712, 14.6731411024, 15.906521414, 13.3244752272, 14.4290206412, 15.3518776304, 14.3108435605, 15.819588301, 15.1230533014, 14.9832654821, 15.0466833033, 15.4870102696, 16.2487803708, 16.0879167412], 
  "fillcolor": "rgb(255,255,255)", 
  "line": {
    "color": "rgb(51,51,51)", 
    "width": 1
  }, 
  "name": "Dec", 
  "showlegend": True, 
  "type": "box", 
  "uid": "472bc9", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace13 = {
  "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Dec", "Dec", "Nov", "Oct", "Sep", "Aug", "Jul", "Jun", "May", "Apr", "Mar", "Feb", "Jan", "Jan"], 
  "y": [15.4791044505, 15.3032746696, 15.2791175743, 15.2848836725, 15.3163590782, 15.2970396934, 15.2816613855, 15.2302020594, 15.2417659333, 15.2782253877, 15.3416460325, 15.5538624276, 14.7826119127, 14.7826119127, 14.859129042, 14.8066220873, 14.7402811367, 14.6944706302, 14.748002775, 14.754522249, 14.7633953772, 14.7767825137, 14.8068033598, 14.8177206774, 14.6914195883, 15.4791044505], 
  "fill": "tozerox", 
  "fillcolor": "rgba(51,51,51,0.2)", 
  "line": {
    "color": "transparent", 
    "dash": "solid", 
    "shape": "linear", 
    "width": 2
  }, 
  "mode": "lines", 
  "name": "Smoothed Fit", 
  "showlegend": True, 
  "type": "scatter", 
  "uid": "988b86", 
  "xaxis": "x", 
  "yaxis": "y"
}
trace14 = {
  "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], 
  "y": [15.0852620194, 15.0604976735, 15.042960467, 15.0308330931, 15.0398772277, 15.0257809712, 15.0148320803, 14.9623363448, 14.991023535, 15.0424237375, 15.1003875372, 15.1682371701], 
  "line": {
    "color": "rgb(51,102,255)", 
    "dash": "solid", 
    "shape": "spline", 
    "smoothing": 1.3, 
    "width": 2
  }, 
  "mode": "lines", 
  "name": "Fit", 
  "showlegend": True, 
  "type": "scatter", 
  "uid": "44d382", 
  "xaxis": "x", 
  "yaxis": "y"
}
data = Data([trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, trace11, trace12, trace13, trace14])
layout = {
  "autosize": True, 
  "height": 523, 
  "legend": {
    "x": 1.05007473842, 
    "y": 1.02040816327, 
    "bgcolor": "rgb(255,255,255)", 
    "bordercolor": "transparent", 
    "font": {"family": ""}, 
    "xanchor": "center", 
    "yanchor": "top"
  }, 
  "margin": {"r": 80}, 
  "paper_bgcolor": "rgb(255,255,255)", 
  "plot_bgcolor": "rgb(229,229,229)", 
  "showlegend": False, 
  "title": "Box plot with Smoothed Fit", 
  "titlefont": {"family": ""}, 
  "width": 829, 
  "xaxis": {
    "autorange": True, 
    "gridcolor": "rgb(255,255,255)", 
    "range": [-0.5, 11.5], 
    "showgrid": True, 
    "showline": False, 
    "showticklabels": True, 
    "tickcolor": "rgb(127,127,127)", 
    "ticks": "outside", 
    "title": "", 
    "type": "category", 
    "zeroline": False
  }, 
  "yaxis": {
    "autorange": True, 
    "gridcolor": "rgb(255,255,255)", 
    "range": [12.3400872989, 17.6876975719], 
    "showgrid": True, 
    "showline": False, 
    "showticklabels": True, 
    "tickcolor": "rgb(127,127,127)", 
    "ticks": "outside", 
    "title": "Thunderstorms", 
    "type": "linear", 
    "zeroline": False
  }
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6be9e22926bc> in <module>
#      13 # Find your api_key here: https://plot.ly/settings/api
#      14
# ---> 15 import plotly as py
#      16 from plotly.graph_objs import *
#      17 py.sign_in('username', 'api_key')
#
# ModuleNotFoundError: No module named 'plotly'
