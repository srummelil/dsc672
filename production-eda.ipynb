# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot
sns.set()
# %matplotlib inline

# %%
prod_df = pd.read_pickle('./processed/production_all_dates_and_variables.pkl')
prod_df.drop('Time', inplace=True, axis=1)
prod_df.head()
# Out:
#                      Wind_KWH  Solar_KWH  Wind_Speed_AT_WINDFARM  \
# Time
# 2010-01-04 15:00:00       0.0   14186.16                     0.0
# 2010-01-04 16:00:00       0.0    5898.00                     0.0
# 2010-01-05 09:00:00       0.0   12421.86                     0.0
# 2010-01-05 10:00:00       0.0   14210.46                     0.0
# 2010-01-05 11:00:00       0.0   14723.64                     0.0
#
#                      Solar_Elevation  Cloud_Cover_Fraction  Dew_Point  \
# Time
# 2010-01-04 15:00:00        21.341264                   1.0       -8.3
# 2010-01-04 16:00:00        16.551903                   1.0       -8.3
# 2010-01-05 09:00:00        -2.457051                   1.0       -8.3
# 2010-01-05 10:00:00         6.474936                   1.0       -8.3
# 2010-01-05 11:00:00        14.045789                   1.0       -7.8
#
#                      Humidity_Fraction  Precipitation  Pressure  Temperature  \
# Time
# 2010-01-04 15:00:00             0.7141            0.0     991.9         -3.9
# 2010-01-04 16:00:00             0.6827            0.0     992.2         -3.3
# 2010-01-05 09:00:00             0.8437            0.0     992.9         -6.1
# 2010-01-05 10:00:00             0.7759            0.0     992.9         -5.0
# 2010-01-05 11:00:00             0.7709            0.0     993.2         -4.4
#
#                      Visibility  Wind_Speed_AT_SOLARRAY
# Time
# 2010-01-04 15:00:00      16.093                     5.7
# 2010-01-04 16:00:00      16.093                     3.6
# 2010-01-05 09:00:00       8.047                     3.1
# 2010-01-05 10:00:00      16.093                     4.1
# 2010-01-05 11:00:00      16.093                     3.6

# %%
#prod_df.set_index('Time', drop=True, inplace=True)
cut = prod_df.loc['2011-03-01':'2013-01-01']

# %%
cut.head()
# Out:
#                                    Time  Wind_KWH  Solar_KWH  \
# Time
# 2011-03-01 08:00:00 2011-03-01 08:00:00       0.0   13658.14
# 2011-03-01 09:00:00 2011-03-01 09:00:00       0.0   41687.98
# 2011-03-01 10:00:00 2011-03-01 10:00:00       0.0  118972.48
# 2011-03-01 11:00:00 2011-03-01 11:00:00       0.0  143772.16
# 2011-03-01 12:00:00 2011-03-01 12:00:00       0.0  190731.62
#
#                      Wind_Speed_AT_WINDFARM  Solar_Elevation  \
# Time
# 2011-03-01 08:00:00                     0.0              0.0
# 2011-03-01 09:00:00                     0.0              0.0
# 2011-03-01 10:00:00                     0.0              0.0
# 2011-03-01 11:00:00                     0.0              0.0
# 2011-03-01 12:00:00                     0.0              0.0
#
#                      Cloud_Cover_Fraction  Dew_Point  Humidity_Fraction  \
# Time
# 2011-03-01 08:00:00                  0.00      -10.6             0.8342
# 2011-03-01 09:00:00                  0.50      -10.6             0.7659
# 2011-03-01 10:00:00                  0.25      -10.0             0.6788
# 2011-03-01 11:00:00                  0.25      -10.0             0.5973
# 2011-03-01 12:00:00                  0.00       -8.9             0.5535
#
#                      Precipitation  Pressure  Temperature  Visibility  \
# Time
# 2011-03-01 08:00:00            0.0    1001.5         -8.3      16.093
# 2011-03-01 09:00:00            0.0    1000.9         -7.2      16.093
# 2011-03-01 10:00:00            0.0    1000.5         -5.0      16.093
# 2011-03-01 11:00:00            0.0     999.9         -3.3      16.093
# 2011-03-01 12:00:00            0.0     998.9         -1.1      16.093
#
#                      Wind_Speed_AT_SOLARRAY
# Time
# 2011-03-01 08:00:00                     2.6
# 2011-03-01 09:00:00                     3.1
# 2011-03-01 10:00:00                     2.6
# 2011-03-01 11:00:00                     4.1
# 2011-03-01 12:00:00                     4.6

# %%
cut.describe().T
# Out:
#                           count          mean           std   min        25%  \
# Wind_KWH                15734.0  11778.141858  12492.859442   0.0  2201.0000
# Solar_KWH               15734.0  32955.808915  51802.235815   0.0     0.0000
# Wind_Speed_AT_WINDFARM  15734.0      5.670599      2.633196   0.0     3.8000
# Solar_Elevation         15734.0      0.000000      0.000000   0.0     0.0000
# Cloud_Cover_Fraction    15734.0      0.432919      0.464269   0.0     0.0000
# Dew_Point               15734.0      5.713716      9.129442 -20.0    -1.7000
# Humidity_Fraction       15734.0      0.692695      0.175481   0.0     0.5744
# Precipitation           15734.0      0.093454      0.864213   0.0     0.0000
# Pressure                15734.0    979.047432    108.759557   0.0   986.9000
# Temperature             15734.0     11.657652     10.041673 -16.1     2.8000
# Visibility              15734.0     14.667236      3.617130   0.0    16.0930
# Wind_Speed_AT_SOLARRAY  15734.0      3.999518      2.478505   0.0     2.6000
#
#                               50%         75%         max
# Wind_KWH                7566.0000  17120.0000   64032.000
# Solar_KWH                  0.0000  50366.9750  205619.360
# Wind_Speed_AT_WINDFARM     5.6000      7.3000      19.800
# Solar_Elevation            0.0000      0.0000       0.000
# Cloud_Cover_Fraction       0.2500      1.0000       1.000
# Dew_Point                  6.1000     13.3000      26.100
# Humidity_Fraction          0.7141      0.8349       1.000
# Precipitation              0.0000      0.0000      41.100
# Pressure                 991.2000    995.6000    1011.200
# Temperature               11.7000     19.4000      37.200
# Visibility                16.0930     16.0930      16.093
# Wind_Speed_AT_SOLARRAY     3.6000      5.1000      18.500

# %%
prod_corr = prod_df.corr()

# %%
fig, ax = pyplot.subplots(figsize=(12,10))
prod_heat = sns.heatmap(ax=ax, data=prod_corr, annot=True)
pyplot.savefig('production_corr_heatmap.png', bbox_inches='tight')

# %%
wind = prod_df.loc['2011-03-01':'2012-12-31']
solar_init = prod_df.loc['2010-01-01':'2014-08-31']
solar = solar_init.between_time('05:00:00', '22:00:00')

# %%
solar_hist = sns.distplot(solar['Solar_KWH'])
pyplot.savefig('solar_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
wind_hist = sns.distplot(wind['Wind_KWH'])
pyplot.savefig('wind_KWH_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
wind_spd_wf_hist = sns.distplot(wind['Wind_Speed_AT_WINDFARM'])
pyplot.savefig('wind_speed_at_windfarm_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
solar_elev_hist = sns.distplot(solar['Solar_Elevation'])
pyplot.savefig('solar_elevation_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
cloud_cover_hist = sns.distplot(solar['Cloud_Cover_Fraction'])
pyplot.savefig('cloud_fraction_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
dew_point_hist = sns.distplot(solar['Dew_Point'])
pyplot.savefig('dew_pnt_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
humidity_hist = sns.distplot(solar['Humidity_Fraction'])
pyplot.savefig('humidity_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
precip_hist = sns.distplot(solar['Precipitation'])
pyplot.savefig('precipitation_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
pressure_hist = sns.distplot(solar['Pressure'])
pyplot.savefig('pressure_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
temp_hist = sns.distplot(solar['Temperature'])
pyplot.savefig('temperature_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
visibility_hist = sns.distplot(solar['Visibility'])
pyplot.savefig('visibility_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
wind_at_solar_hist = sns.distplot(solar['Wind_Speed_AT_SOLARRAY'])
pyplot.savefig('wind_speed_at_solar_histogram.png', bbox_inches='tight')
# Out:
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/johnmatune/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
solar[['Solar_KWH', 'Solar_Elevation', 'Cloud_Cover_Fraction', 'Dew_Point', 'Humidity_Fraction', 'Precipitation' ,'Pressure', 'Temperature', 'Visibility', 'Wind_Speed_AT_SOLARRAY']].describe().T
# Out:
#                           count          mean           std        min  \
# Solar_KWH               23164.0  55443.473511  56848.670552   0.000000
# Solar_Elevation         23164.0      5.668974     14.149297 -10.060352
# Cloud_Cover_Fraction    23164.0      0.449873      0.459878   0.000000
# Dew_Point               23164.0      5.154529     10.073459 -26.100000
# Humidity_Fraction       23164.0      0.656929      0.179824   0.000000
# Precipitation           23164.0      0.080099      0.764164   0.000000
# Pressure                23164.0    692.662178    454.704164   0.000000
# Temperature             23164.0     11.910857     11.184707 -22.800000
# Visibility              23164.0     14.628373      3.740887   0.000000
# Wind_Speed_AT_SOLARRAY  23164.0      4.387210      2.570678   0.000000
#
#                               25%         50%            75%            max
# Solar_KWH               6770.4300  32017.8500  100279.430000  205619.360000
# Solar_Elevation            0.0000      0.0000       0.000000      69.360406
# Cloud_Cover_Fraction       0.0000      0.2500       1.000000       1.000000
# Dew_Point                 -2.8000      5.6000      13.900000      26.100000
# Humidity_Fraction          0.5286      0.6672       0.798675       1.000000
# Precipitation              0.0000      0.0000       0.000000      41.100000
# Pressure                   0.0000    987.9000     993.600000    1011.200000
# Temperature                2.2000     12.8000      21.700000      37.200000
# Visibility                16.0930     16.0930      16.093000      16.093000
# Wind_Speed_AT_SOLARRAY     2.6000      4.1000       5.700000      18.500000

# %%
wind[['Wind_KWH', 'Wind_Speed_AT_WINDFARM']].describe().T
# Out:
#                           count          mean           std  min     25%  \
# Wind_KWH                15726.0  11784.133537  12493.211208  0.0  2204.0
# Wind_Speed_AT_WINDFARM  15726.0      5.673483      2.630757  0.0     3.8
#
#                            50%      75%      max
# Wind_KWH                7576.0  17140.0  64032.0
# Wind_Speed_AT_WINDFARM     5.6      7.3     19.8
